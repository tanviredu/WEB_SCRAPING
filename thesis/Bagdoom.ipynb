# %%
from bs4 import BeautifulSoup
import requests
from difflib import get_close_matches

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://www.bagdoom.com/catalogsearch/result/?q="+str(key)
# Download the page using requests
r = requests.get(url)
# Out:
# mobile

# %%
r.text
# Out:
# '<!DOCTYPE html>\r\n<!--[if lt IE 7]> <html class="ie ie6 lte9 lte8 lte7 no-js" lang="en"> <![endif]-->\r\n<!--[if IE 7]> <html class="ie ie7 lte9 lte8 lte7 no-js" lang="en"> <![endif]-->\r\n<!--[if IE 8]> <html class="ie ie8 lte9 lte8 no-js" lang="en"> <![endif]-->\r\n<!--[if IE 9]> <html class="ie ie9 lte9 no-js" lang="en"> <![endif]-->\r\n<!--[if gt IE 9]> <html class="no-js" lang="en"> <![endif]-->\r\n<!--[if !IE]><html class="no-js" lang="en"><![endif]-->\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\r\n<meta name="google-site-verification" content="sevX25CoU4Z-83rn4qJbYxvBo4IBFtoyG4lJ1YgzLI4" />\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<title>Search results for: \'mobile\'</title>\r\n<meta name="description" content="Bagdoom.com provides best online shopping experience in Bangladesh. Buy Apparels, T-shirts, Electronics, computers, smartphones, watches, sunglasses, perfume, shoes etc." />\r\n<meta name="keywords" content="online shopping, online shopping bangladesh, bd online shop, online shopping in dhaka, lehenga saree, t shirt, tops, polo t shirt, long sleeve dresses, perfume shop, casual dress, online shopping sites, t-shirts for men, mens watch, blazers for men, toys for kids, skin care products, clothing stores online, salwar suit, gifts for boyfriend, online shopping offers, shoes online, womens clothing, electronics stores, jewellery shops, computer accessories, body spray, online shopping fashion, accessories for men, summer shoes for men, bangladeshi dress, ladies clothes shops, online shopping mall, kids shoe stores, cheap womens clothing, cheap online clothing, buy clothes online, girls fashion, mobile phone, kameez, laptop, authentic, original, power bank, panjabi" />\r\n<meta name="robots" content="INDEX,FOLLOW" />\r\n<link rel="alternate" href="http://m.bagdoom.com/catalogsearch/result/?q=mobile" />\r\n<link rel="icon" href="https://d2w3f2xvwxpyyl.cloudfront.net/media/favicon/default/bagdoom_favicon.ico" type="image/x-icon" />\r\n<link rel="shortcut icon" href="https://d2w3f2xvwxpyyl.cloudfront.net/media/favicon/default/bagdoom_favicon.ico" type="image/x-icon" />\r\n<script type="text/javascript" src="https://cdn.jsdelivr.net/npm/mobile-detect@1.4.3/mobile-detect.min.js"></script>\r\n\r\n<!-- share this\r\n<script type="text/javascript">var switchTo5x=true;</script>\r\n<script type="text/javascript" src="http://w.sharethis.com/button/buttons.js"></script>\r\n<script type="text/javascript">stLight.options({publisher: "eb5ff5a4-64c1-4c45-84e1-ef024863d948", doNotHash: false, doNotCopy: false, hashAddressBar: false});</script>\r\n-->\r\n<!-- share -->\r\n\r\n<meta property="og:image" content="https://www.bagdoom.com/skin/frontend/default/bagdoom/images/bagdoom_fb_logo.png" />\r\n<!-- share -->\r\n\r\n\r\n<!--[if lt IE 7]>\r\n<script type="text/javascript">\r\n//<![CDATA[\r\n    var BLANK_URL = \'https://www.bagdoom.com/js/blank.html\';\r\n    var BLANK_IMG = \'https://www.bagdoom.com/js/spacer.gif\';\r\n//]]>\r\n</script>\r\n<![endif]-->\r\n<link rel="stylesheet" type="text/css" href="https://d2w3f2xvwxpyyl.cloudfront.net/media/css_secure/44b54842eeeca2e823bbb69a0fef7a5c.css" media="all" />\n<link rel="stylesheet" type="text/css" href="https://d2w3f2xvwxpyyl.cloudfront.net/media/css_secure/e2a1d12cf389ada81c1c8998c7a7f035.css" media="print" />\n<script type="text/javascript" src="https://d2w3f2xvwxpyyl.cloudfront.net/media/js/9e61944a0093efba8e72c0ecf5f93d17.js"></script>\n<link rel="canonical" href="https://www.bagdoom.com/shopby" />\n<!--[if lt IE 8]>\n<link rel="stylesheet" type="text/css" href="https://d2w3f2xvwxpyyl.cloudfront.net/media/css_secure/de892614321b749850f7fd757b656c43.css" media="all" />\n<![endif]-->\n<!--[if lt IE 7]>\n<scrip ...

# %%
soup = BeautifulSoup(r.content, 'lxml')

# %%
ans= soup.findAll('h2', attrs={'class':'product-name'})

# %%
result=[]
for node in soup.findAll('h2', attrs={'class':'product-name'}):
    result.append(node.find('a').text.strip())

# %%
result
# Out:
# ['SAMSUNG A20 3/32 GB',
#  'Huawei Nova 5T 8GB RAM 128GB ROM',
#  'Huawei Y9 Prime 4GB RAM 128GB ROM',
#  "Men's Mobile Wallet-mpr-001",
#  "Men's Mobile Wallet-mpb-001",
#  'Vivo S1 4GB RAM 128GB ROM',
#  'Mi Power Bank 10000mAh 2i',
#  'Baseus Multi-function Charger',
#  'Selfie Ring - 16 cm',
#  'Wireless Charger Charging Dock Pad',
#  'Vivo Y12 3GB RAM 64GB ROM',
#  'Maximus M-75 Feature Phone',
#  'MI Band 3 Charging Cable',
#  'Mi 18W USB Fast Charger Adapter',
#  'Honor Mini Pocket Photo Printer',
#  'Anker PowerCore 13000mAh 2-Port Portable…',
#  'Oppo A5S 3GB RAM 64GB ROM',
#  'Maximus M83',
#  'Fast Charge Wall Charger MWC-224S',
#  'Travel Adapter TC-225',
#  'Vivo S1 6GB RAM 128GB ROM',
#  '6 Button Optical Gaming Mouse G850 Micro…',
#  'Vivo Y90 2GB RAM 32GB ROM',
#  'Nokia 2.2 3GB RAM 32GB ROM',
#  'Nokia 2.2 2GB RAM 16GB ROM',
#  'Samsung Galaxy A10 2GB 32GB',
#  'Motorola G7 Power 4GB RAM 64GB ROM Smart…',
#  'Motorola  Moto One 4GB RAM 64GB ROM Smar…',
#  'Motorola E5 Plus 3GB RAM 32GB ROM Smartp…',
#  'Huawei Y Max Ram-4gb Rom-128gb',
#  'Huawei CP60 Qi Wireless Fast Charger',
#  'Oppo F11 4GB RAM 64GB ROM',
#  'Xiaomi Mi 4C Wireless Router',
#  'Mi 20000mAh Power Bank 2C',
#  'Mi Power Bank 10000mAh 2i',
#  'Philips 106 Bluetooth Speaker with Built…',
#  'Oppo A1K 2GB RAM 32GB ROM',
#  'Oppo A7 4GB RAM 64GB ROM',
#  'Oppo A3s 2 GB / 16GB',
#  'Mi M12 headphone-13',
#  'AKG wire earphone-12',
#  'GH in earphone-012',
#  'mi piston earphones -11',
#  'Wall Mount  Phone Holder-683',
#  'Waterproof Mobile Bag for Smartphone-850',
#  'Xiaomi Mi Amplificador Pro - 300Mbps WiF…',
#  'Party Mobile Bag-PBH-050',
#  'Party Mobile Bag-PBH-049',
#  'Party Mobile Bag-PBH-048',
#  'Party Mobile Bag-PBH-047',
#  'Party Mobile Bag-PBH-046',
#  'PSP Classic Handheld Gaming 8GB with 100…',
#  'Vivo Y15 4GB RAM 64GB ROM',
#  'Huawei Y7 Pro (2019) 3GB / 64GB',
#  'Mobile Bag-MSHS-R-029',
#  'Mobile Bag-CR-B-39',
#  'Mobile Bag-CR-B-38',
#  'Vision 2:1 Multimedia Speaker Beat-102 8…',
#  'Vivo Y17 4GB RAM 128GB ROM',
#  'Realme 2 Pro 6GB RAM 64GB ROM']

# %%
ans2= soup.findAll('span', attrs={'class':'price'})

# %%
result=[]
for node in soup.findAll('span', attrs={'class':'price'}):
    print (node.text.strip())
# Out:
# Tk. 0
# Tk. 100,000
# Tk. 100,000
# Tk. 200,000
# Tk. 200,000
# Tk. 16,800
# Tk. 49,999
# Tk. 23,999
# Tk. 740
# Tk. 740
# Tk. 25,990
# Tk. 21,990
# Tk. 1,500
# Tk. 1,199
# Tk. 1,300
# Tk. 2,100
# Tk. 1,995
# Tk. 875
# Tk. 16,990
# Tk. 1,020
# Tk. 600
# Tk. 170
# Tk. 1,000
# Tk. 499
# Tk. 16,000
# Tk. 8,960
# Tk. 2,890
# Tk. 16,990
# Tk. 750
# Tk. 1,200
# Tk. 1,149
# Tk. 1,400
# Tk. 1,349
# Tk. 28,990
# Tk. 25,990
# Tk. 850
# Tk. 749
# Tk. 10,990
# Tk. 9,990
# Tk. 12,999
# Tk. 10,999
# Tk. 11,990
# Tk. 11,699
# Tk. 18,990
# Tk. 17,489
# Tk. 20,990
# Tk. 19,890
# Tk. 14,990
# Tk. 13,999
# Tk. 21,999
# Tk. 20,999
# Tk. 3,399
# Tk. 25,990
# Tk. 3,000
# Tk. 1,399
# Tk. 2,000
# Tk. 1,899
# Tk. 1,500
# Tk. 1,199
# Tk. 2,000
# Tk. 1,340
# Tk. 12,990
# Tk. 19,990
# Tk. 12,990
# Tk. 170
# Tk. 162
# Tk. 175
# Tk. 167
# Tk. 170
# Tk. 162
# Tk. 175
# Tk. 167
# Tk. 253
# Tk. 221
# Tk. 253
# Tk. 220
# Tk. 1,098
# Tk. 899
# Tk. 144
# Tk. 144
# Tk. 144
# Tk. 144
# Tk. 360
# Tk. 4,000
# Tk. 2,499
# Tk. 18,990
# Tk. 15,999
# Tk. 204
# Tk. 180
# Tk. 180
# Tk. 3,000
# Tk. 2,700
# Tk. 22,990
# Tk. 20,990
# Tk. 24,990

# %%
ans2= soup.findAll('div', attrs={'class':'catalog_hover'})

# %%
d={}
for item in ans2:
    a=item.find('h2', attrs={'class':'product-name'}).text.strip()
    b=item.find('div', attrs={'class':'price-box'}).text[:20].strip()
    d.update({a:b})

# %%
d
# Out:
# {'SAMSUNG A20 3/32 GB': 'Tk. 16,800',
#  'Huawei Nova 5T 8GB RAM 128GB ROM': 'Tk. 49,999',
#  'Huawei Y9 Prime 4GB RAM 128GB ROM': 'Tk. 23,999',
#  "Men's Mobile Wallet-mpr-001": 'Tk. 740',
#  "Men's Mobile Wallet-mpb-001": 'Tk. 740',
#  'Vivo S1 4GB RAM 128GB ROM': '',
#  'Mi Power Bank 10000mAh 2i': '',
#  'Baseus Multi-function Charger': 'Tk. 1,300',
#  'Selfie Ring - 16 cm': '',
#  'Wireless Charger Charging Dock Pad': 'Tk. 875',
#  'Vivo Y12 3GB RAM 64GB ROM': 'Tk. 16,990',
#  'Maximus M-75 Feature Phone': 'Tk. 1,020',
#  'MI Band 3 Charging Cable': '',
#  'Mi 18W USB Fast Charger Adapter': '',
#  'Honor Mini Pocket Photo Printer': '',
#  'Anker PowerCore 13000mAh 2-Port Portable…': 'Tk. 2,890',
#  'Oppo A5S 3GB RAM 64GB ROM': 'Tk. 16,990',
#  'Maximus M83': 'Tk. 750',
#  'Fast Charge Wall Charger MWC-224S': '',
#  'Travel Adapter TC-225': '',
#  'Vivo S1 6GB RAM 128GB ROM': '',
#  '6 Button Optical Gaming Mouse G850 Micro…': '',
#  'Vivo Y90 2GB RAM 32GB ROM': '',
#  'Nokia 2.2 3GB RAM 32GB ROM': 'Tk. 12,999',
#  'Nokia 2.2 2GB RAM 16GB ROM': 'Tk. 10,999',
#  'Samsung Galaxy A10 2GB 32GB': '',
#  'Motorola G7 Power 4GB RAM 64GB ROM Smart…': '',
#  'Motorola  Moto One 4GB RAM 64GB ROM Smar…': '',
#  'Motorola E5 Plus 3GB RAM 32GB ROM Smartp…': '',
#  'Huawei Y Max Ram-4gb Rom-128gb': '',
#  'Huawei CP60 Qi Wireless Fast Charger': 'Tk. 3,399',
#  'Oppo F11 4GB RAM 64GB ROM': 'Tk. 25,990',
#  'Xiaomi Mi 4C Wireless Router': '',
#  'Mi 20000mAh Power Bank 2C': '',
#  'Philips 106 Bluetooth Speaker with Built…': '',
#  'Oppo A1K 2GB RAM 32GB ROM': 'Tk. 12,990',
#  'Oppo A7 4GB RAM 64GB ROM': 'Tk. 19,990',
#  'Oppo A3s 2 GB / 16GB': 'Tk. 12,990',
#  'Mi M12 headphone-13': '',
#  'AKG wire earphone-12': '',
#  'GH in earphone-012': '',
#  'mi piston earphones -11': '',
#  'Wall Mount  Phone Holder-683': '',
#  'Waterproof Mobile Bag for Smartphone-850': '',
#  'Xiaomi Mi Amplificador Pro - 300Mbps WiF…': '',
#  'Party Mobile Bag-PBH-050': 'Tk. 144',
#  'Party Mobile Bag-PBH-049': 'Tk. 144',
#  'Party Mobile Bag-PBH-048': 'Tk. 144',
#  'Party Mobile Bag-PBH-047': 'Tk. 144',
#  'Party Mobile Bag-PBH-046': 'Tk. 360',
#  'PSP Classic Handheld Gaming 8GB with 100…': '',
#  'Vivo Y15 4GB RAM 64GB ROM': 'Tk. 18,990',
#  'Huawei Y7 Pro (2019) 3GB / 64GB': 'Tk. 15,999',
#  'Mobile Bag-MSHS-R-029': 'Tk. 204',
#  'Mobile Bag-CR-B-39': 'Tk. 180',
#  'Mobile Bag-CR-B-38': 'Tk. 180',
#  'Vision 2:1 Multimedia Speaker Beat-102 8…': '',
#  'Vivo Y17 4GB RAM 128GB ROM': '',
#  'Realme 2 Pro 6GB RAM 64GB ROM': 'Tk. 24,990'}
