# %%
from bs4 import BeautifulSoup
import requests
from difflib import get_close_matches

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://www.shadmart.com/index.php?route=product/search&search="+str(key)
# Download the page using requests
r = requests.get(url)
# Out:
# mobile

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" lang="en" class="firefox firefox60 linux journal-desktop is-guest skin-10 responsive-layout bottom-menu-bar infinite-scroll center-header mega-header lang-full lang-full-mobile currency-full currency-full-mobile extended-layout header-center header-sticky sticky-menu backface product-grid-second-image product-list-second-image search-page layout-17 route-product-search oc2" data-j2v="2.15.8">\n<head>\n    <meta charset="UTF-8" />\n\n\t\t\t\t        \n\t\t\t            <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no">\n\t\t\t    <meta name="format-detection" content="telephone=no">\n    <!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1"/><![endif]-->\n    <title>Search - mobile</title>\n    <base href="https://www.shadmart.com/" />\n\t\t\t\t            <meta property="og:title" content="Shadmart.com" />\n\t            <meta property="og:site_name" conte
# ...

# %%
soup = BeautifulSoup(r.content, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="firefox firefox60 linux journal-desktop is-guest skin-10 responsive-layout bottom-menu-bar infinite-scroll center-header mega-header lang-full lang-full-mobile currency-full currency-full-mobile extended-layout header-center header-sticky sticky-menu backface product-grid-second-image product-list-second-image search-page layout-17 route-product-search oc2" data-j2v="2.15.8" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1"/><![endif]-->
# <title>Search - mobile</title>
# <base href="https://www.shadmart.com/"/>
# <meta content="Shadmart.com" property="og:title"/>
# <meta content="Shadmart.com" property="og:site_name"/>
# ...

# %%
ans= soup.findAll('h4', attrs={'class':'name'})

# %%
for item in ans:
    print (item.text.strip()[:20])
# Out:
# Newman M560 long sta
# Baidu network disk s
# Huawei's honor / glo
# 10 yuan/month baidu
# Vivo Z5x pole compre
# Huawei's HONOR / glo
# Newman L6 + super lo
# Full Netcom 4G Mobil
# Vivo Z5 new vivoz5 l
# Huawei's HONOR / glo
# Huawei's HONOR / glo
# Huawei's HONOR/Glory
# Caring for old age h
# [4G Full Netcom] New
# vivo U3x New vivou3x
# 4G Xuan Hao entire n
# YEPEN / Fitch goods
# Vivo iqoo Neo 855 Qu
# Newman F9 elderly fl
# Newman child W560 mo

# %%
ans= soup.findAll('span', attrs={'class':'price-new'})

# %%
for item in ans:
    print (item.text.strip()[:20])
# Out:
# tk.2,626
# tk.18,407
# tk.19,789
# tk.14,217
# tk.2,626
# tk.2,626
# tk.18,407
# tk.28,182
# tk.32,372
# tk.2,472
# tk.2,472
# tk.2,347
# tk.2,431
# tk.4,009
# tk.2,752

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://www.shopclues.com/search?q="+str(key)
# Download the page using requests
r = requests.get(url)
# Out:
# iphone

# %%
r.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n   <meta charset="utf-8">\r\n <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\r\n <link rel="dns-prefetch" href="//ads.yahoo.com" />\r\n <!-- <link rel="dns-prefetch" href="//analytics.twitter.com" />-->\r\n <link rel="dns-prefetch" href="//api.targetingmantra.com" />\r\n <link rel="dns-prefetch" href="//api.apac-sg.zettata.com" />\r\n <link rel="dns-prefetch" href="//assets.adobedtm.com" />\r\n <link rel="dns-prefetch" href="//a.adroll.com" />\r\n <link rel="dns-prefetch" href="//cdn.atomex.net" />\r\n <link rel="dns-prefetch" href="//cdn.shopclues.net" />\r\n <link rel="dns-prefetch" href="//cdn.shopclues.com" />\r\n <link rel="dns-prefetch" href="//connect.facebook.net" />\r\n<!-- <link rel="dns-prefetch" href="//cluesnetwork.sc.omtrdc.net" />-->\r\n <link rel="dns-prefetch" href="//d.adroll.com" />\r\n <link rel="dns-prefetch" href="//datacdn.atomex.net" />\r\n <link rel="dns-prefe
# ...

# %%
soup = BeautifulSoup(r.content, 'lxml')

# %%
ans= soup.findAll('div', attrs={'class':'column col3 search_blocks'})

# %%
for
# Out:
# [<div class="column col3 search_blocks">
#  <!-- <a class="whishlist_ic" pid ="147500329"  href="javascript:void(0);"></a> -->
#  <a href="//www.shopclues.com/apple-iphone-7-32gb-2-gb-ram-refurbished-mobile-phone-147500329.html" target="_blank">
#  <div class="img_section">
#  <img alt="Apple iPhone 7 32GB, 2 GB RAM Refurbished Mobile Phone" border="0" class="" data-img="https://cdn.shopclues.com/images1/thumbnails/102276/200/200/147500329-102276469-1565175070.jpg" height="200" id="det_img_147500329" onclick="homePageTracking(this);" sizes="1" src="https://cdn.shopclues.com/images1/thumbnails/102276/200/200/147500329-102276469-1565175070.jpg" title="Apple iPhone 7 32GB, 2 GB RAM Refurbished Mobile Phone" width="200"/>
#  </div>
#  <h2>Apple iPhone 7 32GB, 2 GB RAM Refurbished Mobile Phone</h2>
#  <div class="prd_p_section">
#  <div class="ori_price">
#  <span class="p_price">Rs.17999                                             </span>
#  <span class="prd_discount">22% Off</span>
# ...

# %%
for node in soup.findAll('div', attrs={'class':'column col3 search_blocks'}):
    print (node.find('h2').text)
# Out:
# Apple iPhone 7 32GB, 2 GB RAM Refurbished Mobile Phone
# Apple iPhone 6 64 Gb Refurbished Mobile Phone
# Apple iPhone 4 16GB (Refurbished) (1 Year Warranty Baza
# APPLE IPHONE 7 PLUS 256GB Black Refurbished Phone
# Certified Used Apple iPhone 5s-Space Grey-16 GB-1 GB-Ph
# Apple iphone 6 16 Gb Refurbished Mobile Phone
# Iphone 5s 16 gb refurbished phone
# Iphone 5s 16 gb refurbished phone
# Apple iPhone 4 8GB white(Refurbished)
# Apple iPhone 7 32GB, 2 GB RAM Refurbished Mobile Phone
# Refurbished Apple iPhone 5 16GB Black
# Refurbished Apple iPhone 4 8GB 512MB RAM Black 1 GHz Pr

# %%
for node in soup.findAll('div', attrs={'class':'column col3 search_blocks'}):
    print (node.find('span', attrs={'class':'p_price'}).text.strip())
# Out:
# Rs.17999
# Rs.12399
# Rs.3599
# Rs.33999
# Rs.7299
# Rs.8599
# Rs.8499
# Rs.8499
# Rs.3199
# Rs.17699
# Rs.7299
# Rs.3399

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://paytm.com/shop/search?q="+str(key)
# Download the page using requests
r = requests.get(url)
# Out:
# iphone

# %%
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
ans= soup.findAll('div', attrs={'class':'_2apC'})

# %%
for item in soup.findAll('div', attrs={'class':'_2apC'}):
    print (item.text.strip())
# Out:
# XS Cricket Bat Scuff Sheet Fibre glass Tape F ...
# Display LCD Touch Screen Digitizer + Front Ca ...
# iPhone 3G / 3GS Tight Grip Pair of Screen Pro ...
# NEW Apple19Michael11Kors47MK9Coach Fits iPhon ...
# AT&T Apple Iphone 4 Case Cover Silicone Clear ...
# NEW Custom Michael10Kors33MK9Coach Fits iPhon ...
# for iPhone 4 4th Gen Case Skin Smoke Gel+Leat ...
# Vest Anti-Radiation Case Cover Radiation Prot ...
# XS Power 586 Tall Brass Post Adaptors M6 for  ...
# iPhone XR / Xs Max Shockproof Slim PC+TPU Cas ...
# AT&T Apple iPhone 4 - Premium Smoke Soft Sili ...
# XSories XShine Combo LED Spotlight w/ U-Shot  ...
# XS Power RT0L-RD-100PK 0 AWG Gauge 10.5MM Nic ...
# Iphone Xs Max Case Black Slim Thin Silicone S ...
# Custom Coach75Colorfull19MK20LV Fits iPhone 8 ...
# XS Power TB-606V2 PAIR of 6-Spot 1/0 M6/M8 Al ...
# AT&T Apple Iphone 4 Case Cover Silicone Clear ...
# AT&T Apple Iphone 4 Case Cover Silicone Neon  ...
# AT&T Apple Iphone 4 Case Cover Silicone Laven ...
# ...

# %%
for item in soup.findAll('span', attrs={'class':'_1kMS'}):
    print (item.text.strip())
# Out:
# Rs 180
# Rs 4571
# Rs 1039
# Rs 2859
# Rs 902
# Rs 2859
# Rs 902
# Rs 4472
# Rs 1547
# Rs 1346
# Rs 1305
# Rs 1245
# Rs 10619
# Rs 1662
# Rs 2859
# Rs 8704
# Rs 902
# Rs 902
# Rs 902
# Rs 4571
# Rs 1581
# Rs 10619
# Rs 1305
# Rs 2859
# Rs 5579
# Rs 2001
# Rs 902
# Rs 1717
# Rs 64900
# Rs 210280

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://ofuronto.com/?s="+str(key)+"&post_type=product"
# Download the page using requests
r = requests.get(url)
# Out:
# samsung

# %%
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 9 ]> <html lang="en-US" class="ie9 loading-site no-js"> <![endif]--><!--[if IE 8 ]> <html lang="en-US" class="ie8 loading-site no-js"> <![endif]--><!--[if (gte IE 9)|!(IE)]><!--><html class="loading-site no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://ofuronto.com/xmlrpc.php" rel="pingback"/>
# <script>document.documentElement.className = document.documentElement.className + ' yes-js js_active js'</script>
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <title>You searched for samsung – Ofuronto.com</title>
# <script data-cfasync="false" data-pagespeed-no-defer="" type="text/javascript">//<![CDATA[
# 	var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
# 	var gtm4wp_use_sku_instead        = 0;
# 	var gtm4wp_id_prefix              = '';
# ...

# %%
for item in soup.findAll('p', attrs={'class':'name product-title'}):
    print (item.text.strip())
# Out:
# Samsung Galaxy J2 2018 ৩৬০ ডিগ্রি ফোন কেস ব্ল্যাক এবং রেড
# Samsung Galaxy M20 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy M20 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy M10 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy M10 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J7 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J7 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J6 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J6 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J5 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J5 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J4 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J4 ম্যাক্স স্ক্রাচ প্রতিরোধী ব্যাক কভার
# Samsung Galaxy J3 স্মার্ট লুকিং ম্যাক্স ব্যাক কভার
# স্টাইলিশ স্ক্র্যাচ প্রতিরোধক Samsung Galaxy J2 ব্যাক কভার
# Samsung Galaxy J2 ম্যাক্স ব্যাক কভার
# Samsung গ্যালাক্সি J1 ম্যাক্স ব্যাক কভার
# ...

# %%
for item in soup.findAll('span', attrs={'class':'woocommerce-Price-amount amount'}):
    print (item.text.strip())
# Out:
# ৳ 0.00
# ৳ 400.00
# ৳ 250.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 130.00
# ৳ 400.00
# ৳ 158.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 400.00
# ৳ 160.00
# ৳ 500.00
# ৳ 150.00
# ৳ 950.00
# ৳ 390.00
# ৳ 650.00
# ৳ 350.00
# ৳ 1,290.00
# ৳ 630.00
# ৳ 220.00
# ৳ 120.00
# ৳ 790.00
# ৳ 790.00
# ৳ 400.00
# ৳ 250.00
# ৳ 249.00
# ৳ 249.00
# ৳ 249.00
# ৳ 249.00
# ৳ 249.00
# ৳ 249.00
# ৳ 200.00
# ৳ 120.00
# ৳ 250.00
# ৳ 99.00
# ৳ 799.00
# ৳ 649.00
# ৳ 990.00
# ৳ 990.00
# ৳ 2,500.00
# ৳ 1,197.00
# ৳ 3,200.00
# ৳ 1,560.00
# ৳ 3,200.00
# ৳ 1,560.00
# ৳ 550.00
# ৳ 299.00
# ৳ 1,280.00
# ৳ 1,550.00
# ৳ 990.00
# ৳ 1,550.00
# ৳ 990.00
# ৳ 990.00
# ৳ 617.00
# ৳ 7,550.00
# ৳ 4,980.00
# ৳ 700.00
# ৳ 347.00
# ৳ 1,570.00
# ৳ 350.00
# ৳ 290.00
# ৳ 550.00
# ৳ 290.00

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://priyoshop.com/src?q="+str(key)
# Download the page using requests
r = requests.get(url)
# Out:
# samsung

# %%
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="html-search-page">
# <head>
# <title>PriyoShop.com - Online Shopping in Bangladesh</title>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <meta content="Trusted Online Shopping in Bangladesh" name="title"/>
# <meta content="Online shopping in Bangladesh for men, women &amp;amp; kids. Buy dress, gift item, beauty products, unique items, jewelry, watch, electronics at PriyoShop.com" name="description"/>
# ...

# %%
for item in soup.findAll('h2', attrs={'class':'product-title'}):
    print (item.text.strip())
# Out:
# Samsung Premium 65 Inch UHD 4K Curved Smart TV - 65MU9500
# Samsung HD TV 32 Inch - UA32N4100AR
# Samsung Flat 65 Inch 4K UHD Smart TV - 65NU7100
# Samsung Flat 55 Inch 4K UHD Smart TV 55NU7100
# Samsung Electronics 82 Inch 4K Ultra HD Smart TV - 82MU8000
# Samsung Electronics 65 Inch 4K Ultra HD Smart LED TV - 65MU9000
# Samsung Curved 65 Inch 4K Ultra HD Smart LED TV - 65KU6500
# Samsung Curved 65 Inch 4K UHD Smart TV - 65NU7300
# Samsung Curved 55 Inch 4K 7 Series Smart TV - 55NU7300
# Samsung Canister Vacuum Cleaner - VC18M2120
# Samsung 970 EVO Plus NVMe M.2 250GB SSD
# Samsung 970 EVO Plus 500GB NVMe M.2 SSD
# Samsung 860 QVO 1TB 2.5 Inch SATA III SSD
# Samsung 860 Evo 500GB 2.5 Inch Internal SSD
# Samsung 860 EVO 250GB 2.5 Inch SATA III SSD
# Samsung 65 Inch Flat Smart 4K UHD TV - 65MU6100
# Samsung 55 Inch UHD Curved Smart LED TV - 55MU7350
# Samsung 55 Inch QLED Ultra HD 4K TV - 55Q8C
# Samsung 55 Inch Q Series 4K UHD Smart TV - 55Q7FN
# ...

# %%
for item in soup.findAll('span', attrs={'class':'price actual-price'}):
    print (item.text.strip())
# Out:
# Tk 267,750
# Tk 25,900
# Tk 139,650
# Tk 77,700
# Tk 514,500
# Tk 252,000
# Tk 189,000
# Tk 168,000
# Tk 94,500
# Tk 9,900
# Tk 6,300
# Tk 11,000
# Tk 10,000
# Tk 6,600
# Tk 4,650
# Tk 141,750
# Tk 96,600
# Tk 162,750
# Tk 168,000
# Tk 82,950
# Tk 157,500

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://www.allmartbd.com/catalogsearch/result/?q="+str(key)
# Download the page using requests
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# samsung
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Search results for: 'samsung'</title>
# <meta content="Default Description" name="description"/>
# <meta content="Magento, Varien, E-commerce" name="keywords"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.allmartbd.com/media/favicon/default/fav.png" rel="icon" type="image/x-icon"/>
# <link href="https://www.allmartbd.com/media/favicon/default/fav.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="//fonts.googleapis.com/css?family=Open+Sans%3A300%2C300italic%2C400%2C400italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic&amp;v1&amp;subset=latin%2Clatin-ext" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=Shadows+Into+Light" rel="stylesheet" type="text/css"/>
# ...

# %%
for item in soup.findAll('h2', attrs={'class':'product-name'}):
    print (item.text.strip())
# Out:
# FM Transmitter
# Samsung Evo Plus 16GB 256mb/s Class 10 Micro SD Memory
# Opening Tool Set for iPhone, Samsung
# APDS9960 RGB and Gesture Sensor
# 15 in 1 Precision Screwdrivers + Opening Set
# YX-6025 Repair Tool
# Samsung Earphones with Mic - White
# Rechargeable Smart Portable light
# Samsung Mobile Charger
# USB 10 in 1 Multi Charger Cable

# %%
for item in soup.findAll('span', attrs={'class':'price'}):
    print (item.text.strip())
# Out:
# Tk 550.00
# Tk 520.00
# Tk 130.00
# Tk 899.00
# Tk 490.00
# Tk 340.00
# Tk 99.00
# Tk 340.00
# Tk 118.00
# Tk 59.00

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://www.edokandar.com/catalogsearch/result/?q="+str(key)
# Download the page using requests
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# samsung
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="en" id="top" class="no-js ie6"> <![endif]--><!--[if IE 7 ]>    <html lang="en" id="top" class="no-js ie7"> <![endif]--><!--[if IE 8 ]>    <html lang="en" id="top" class="no-js ie8"> <![endif]--><!--[if IE 9 ]>    <html lang="en" id="top" class="no-js ie9"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" id="top" lang="en"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Search results for: 'samsung'</title>
# <meta content="Online Shopping Site in Bangladesh for Mobiles, Gadgets, Electronics, Fashions and Many More . eDokandar.com" name="description"/>
# <meta content="" name="keywords"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://www.edokandar.com/media/favicon/default/icon_1.png" rel="icon" type="image/x-icon"/>
# ...

# %%
for item in soup.findAll('h2', attrs={'class':'product-name'}):
    print (item.text.strip())
# Out:
# Samsung Galaxy J8 4GB RAM + 64 GB ROM
# Samsung Galaxy M20
# Samsung Galaxy A50
# Samsung Galaxy A30
# Samsung Galaxy A20-Blue
# Samsung Galaxy A20-Black
# Samsung Galaxy M10 2GB 16GB
# Samsung Galaxy A9 6GB - 128 GB
# Samsung Galaxy A6 Plus 2018
# Samsung Galaxy A7 (2018) 4GB/64GB
# Samsung Galaxy J2 Prime 2018
# Samsung Galaxy TAB 3V
# Samsung Galaxy Tab A7
# Samsung Galaxy J6 2018 3GB/32GB
# Samsung Galaxy J4 2018 2GB/16GB
# Samsung Galaxy J2 2018
# Samsung Metro 350-greenish blue
# Samsung Metro 350
# Samsung Galaxy S9 Plus
# Samsung Galaxy A70

# %%
for item in soup.findAll('span', attrs={'class':'regular-price'}):
    print (item.text.strip())
# Out:
# Tk 15,990
# Tk 24,990
# Tk 20,990
# Tk 15,990
# Tk 15,990
# Tk 11,999
# Tk 8,990
# Tk 12,490
# Tk 14,900
# Tk 14,990
# Tk 11,990
# Tk 9,990
# Tk 3,550
# Tk 3,550
# Tk 38,990

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://clicxo.com.bd/en/catalogsearch/result/?q="+str(key)
# Download the page using requests
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# samsung
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <script>
#     var BASE_URL = 'https://clicxo.com.bd/en/';
#     var require = {
#         "baseUrl": "https://clicxo.com.bd/pub/static/frontend/bs_complex/bs_complex1/en_US"
#     };
# </script>
# <meta charset="utf-8"/>
# <meta content="Shop online in Bangladesh with best deals for Mobiles, Electronics, Fashion &amp; Everything you need" name="description"/>
# <meta content="Shop online in Bangladesh with best deals for Mobiles, Electronics, Fashion &amp; Everything you need" name="keywords"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <meta content="Search results for: 'samsung'" name="title"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>Search results for: 'samsung'</title>
# <link href="https://clicxo.com.bd/pub/static/_cache/merged/65514cd9098d16c55002718b55d555e8.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
for item in soup.findAll('a', attrs={'class':'product-item-link'}):
    print (item.text.strip())
# Out:
# QKZ CK8 In-Ear Super Bass earphone with Microphone Hifi Headsets For Samsung iPhone Xiaomi Huawei
# UiiSii HM9 Wired Noise Cancelling Dynamic Heavy Bass Music Metal In-ear with Mic for iphone Xiaomi Samsung
# Samsung In-Ear Headphone (copy)-107
# SAMSUNG GALAXY A20 MOBILE
# SAMSUNG MOBILE GURU MUSIC 2 of 2019
# SAMSUNG MOBILE A2 CORE
# SAMSUNG MOBILE GALAXY A30S PRISM CRUSH BLACK or VIOLET
# SAMSUNG MOBILE A70 6GB 128GB BLUE/WHITE OFFICIAL
# QKZ CK5 Earphone Sport Earbuds Stereo For Apple Xiaomi Samsung With HD Mic
# SAMSUNG B313 BLACK COLOR
# SAMSUNG MOBILE GALAXY M40 BLACK OFFICIAL
# SAMSUNG MOBILE GALAXY A50S PRISM CRUSH BLACK
# SAMSUNG MOBILE A70 8GB 128GB BLUE COLOR
# SAMSUNG MOBILE A70 8GB 128GB BLACK COLOR
# SAMSUNG MOBILE A70 6GB 128GB WHITE COLOR
# SAMSUNG MOBILE GALAXY A50S PRISM CRUSH WHITE COLOR
# SAMSUNG MOBILE GALAXY A50S PRISM CRUSH VIOLET COLOR
# SAMSUNG MOBILE GALAXY C5 GOLD COLOR
# SAMSUNG MOBILE GALAXY A30 RED COLOR
# ...

# %%
for item in soup.findAll('span', attrs={'class':'price'}):
    print (item.text.strip())
# Out:
# ৳320.00
# ৳369.00
# ৳99.00
# ৳15,990.00
# ৳2,100.00
# ৳7,590.00
# ৳22,990.00
# ৳38,900.00
# ৳340.00
# ৳2,750.00
# ৳30,990.00
# ৳29,900.00
# ৳35,500.00
# ৳44,000.00
# ৳35,500.00
# ৳44,000.00
# ৳33,500.00
# ৳44,000.00
# ৳29,900.00
# ৳29,900.00
# ৳15,000.00
# ৳18,000.00
# ৳22,990.00
# ৳22,990.00
# ৳15,990.00
# ৳7,590.00
# ৳3,550.00
# ৳3,550.00

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url="https://www.megashopbd.com/index.php?route=product/search&search="+str(key)+"&description=true"
# Download the page using requests
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# samsung
# <!DOCTYPE html>
# <html class="unknown unknownunknown journal-desktop is-guest skin-10 responsive-layout bottom-menu-bar infinite-scroll center-header mega-header lang-flag lang-flag-mobile currency-symbol currency-symbol-mobile collapse-footer-columns extended-layout header-center header-sticky sticky-menu backface product-grid-second-image product-list-second-image search-page layout-17 route-product-search oc2 one-column no-language" data-j2v="2.16.1" dir="ltr" lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><meta content="telephone=no" name="format-detection"/>
# <!--[if IE]><meta
# ...

# %%
for item in soup.findAll('h4', attrs={'class':'name'}):
    print (item.text.strip())
# Out:
# Samsung 7 Inch Tablet (Replica)
# 2.4GHz Wireless Optical Pen Mouse
# REMAX Quick Charge and Data Sync Cable For Android - Black
# REMAX RL-S20 Audio Sharing Cable
# REMAX Rm-c13 Car Phone Hol
# REMAX RP-U26 Adapter 2 USB Charger
# VR BOX VR Box 2 VR Gear - White

# %%
for item in soup.findAll('p', attrs={'class':'price'}):
    print (item.text.strip())
# Out:
# ৳ 4,000.00
# ৳ 750.00
# ৳ 600.00
# ৳ 499.00
# ৳ 750.00
# ৳ 799.00
# ৳ 570.00

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url= "https://ponnobd.com/?s="+str(key)+"&post_type=product"
# Download the page using requests
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# samsung
# <!DOCTYPE html>
# ...

# %%
for item in soup.findAll('div', attrs={'class':'product-loop-title'}):
    print (item.text.strip())
# Out:
# Samsung 65 Inch 4K Smart UHD TV 65QLED
# Samsung 43 Inch 4K Smart TV 43NU7100
# Samsung 49 Inch 4K Smart TV 49NU7100
# Samsung 49 Inch 4K Curved Smart TV 49MU7350
# Samsung 55 Inch 4K Smart TV 55NU7100
# Samsung 55 Inch Curved 4K Smart TV 55NU7300
# Samsung 55 Inch 4K Smart TV 55MU6100
# Samsung 55 Inch 4K Smart TV 55MU6400
# Samsung 55 Inch Curved Smart TV 55MU7350
# Samsung 65MU7000  65 Inch 4K Smart UHD LED TV
# Samsung 65NU7300  65 Inch Smart 4K UHD TV
# Samsung 65NU7400 65 Inch 4k Ultra HD Smart TV
# Samsung 65NU8000 65 Inch 4K UHD Premium Smart TV
# Samsung 55Q7F 55 Inch QLED 4K HDR Smart TV
# Samsung 65Q6F 65 Inch QLED 4K Ultra HD Smart TV
# Samsung 82MU8000 82 Inch 4K Premium LED TV
# Samsung 65MU9000 65 Inch 4K Smart TV
# Samsung 55KS9000 55 Inch 4K Ultra HD Smart TV
# Samsung 50MU7000 50 Inch Flat UHD Smart TV
# Samsung 49K5100 49 Inch Full HD LED TV
# Samsung 43MU7000 43 Inch 4K Smart TV
# Samsung 40M5000 40 Inch Full HD TV
# Samsung 32J4303 32 Inch HD Flat Smart TV
# ...

# %%
for item in soup.findAll('span', attrs={'class':'woocommerce-Price-amount amount'}):
    print (item.text.strip())
# Out:
# ৳ 485,000
# ৳ 355,000
# ৳ 89,500
# ৳ 58,000
# ৳ 113,500
# ৳ 74,000
# ৳ 120,000
# ৳ 76,000
# ৳ 147,000
# ৳ 96,000
# ৳ 147,000
# ৳ 99,000
# ৳ 137,500
# ৳ 98,000
# ৳ 172,800
# ৳ 115,000
# ৳ 155,200
# ৳ 112,000
# ৳ 248,000
# ৳ 155,000
# ৳ 275,000
# ৳ 172,000
# ৳ 272,000
# ৳ 170,000
# ৳ 360,000
# ৳ 225,000
# ৳ 272,000
# ৳ 170,000
# ৳ 432,000
# ৳ 270,000
# ৳ 848,000
# ৳ 530,000
# ৳ 343,500
# ৳ 316,000
# ৳ 321,500
# ৳ 201,000
# ৳ 156,000
# ৳ 97,500
# ৳ 87,000
# ৳ 57,000
# ৳ 72,500
# ৳ 66,000
# ৳ 41,000
# ৳ 37,000
# ৳ 34,500
# ৳ 32,000
# ৳ 46,500
# ৳ 43,000

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
headers = {'User-Agent': user_agent}
key=input()
url= "https://www.sonalibazar.com/index.php?route=product/search&search="+str(key)
# Download the page using requests
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
soup
# Out:
# samsung
# <!DOCTYPE html>
# <!--[if IE]><![endif]--><!--[if IE 8 ]><html dir="ltr" lang="en" class="ie8"><![endif]--><!--[if IE 9 ]><html dir="ltr" lang="en" class="ie9"><![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html dir="ltr" lang="en">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Search - samsung</title>
# <base href="https://www.sonalibazar.com/"/>
# <!-- Load essential resources -->
# <script src="catalog/view/javascript/jquery/jquery-2.1.1.min.js"></script>
# <link href="catalog/view/javascript/bootstrap/css/bootstrap.min.css" media="screen" rel="stylesheet"/>
# <script src="catalog/view/javascript/bootstrap/js/bootstrap.min.js"></script>
# <script src="catalog/view/theme/basel/js/slick.min.js"></script>
# <script src="catalog/view/theme/basel/js/basel_common.js"></script>
# <!-- Main stylesheet -->
# ...

# %%
for item in soup.findAll('a', attrs={'class':'product-name'}):
    print (item.text.strip())
# Out:
# 2 in 1 REMAX Fast Charging Data Cable
# Mobile Selfie Stick &  Camera Stand
# Nano SIM Adapter Converter - Multicolor
# REMAX E5 5000mAh PRODA Power Bank
# REMAX RL-S20 Audio Sharing Cable-Black
# REMAX RL-S20 Audio Sharing Cable-Golden
# REMAX RL-S20 Audio Sharing Cable-white
# Three Generation Drive-By-Wire Selfie Stick–Black
# Three Generation Drive-By-Wire Selfie Stick–Multicolor
# Shinecon Version 2 VR Box+VR Remote

# %%
for item in soup.findAll('div', attrs={'class':'price'}):
    print (item.text.strip())
# Out:
# ৳  499
# ৳  650
# ৳  19
# ৳  780
# ৳  495
# ৳  495
# ৳  495
# ৳  299
# ৳  239
# ৳  699
